# %% [markdown]
# # 120 sample run results:
# Took approximately 3hrs to run. The error in the autocorrelation time output was not resolved. I think I am misunderstanding what the autocorrelation time is telling me and how to use the output to my advantage.
#
# However, I do believe that the longer sampling worked! I think the results were much better. Looking at the walker position plot it seems that the sampler recognized it was best to make logT_AGN as negative as it could go. Unfortunately, I made the lower bound on logT_AGN -5, so it couldn't go much smaller than -5. However, it recognized the better fit was found when logT_AGN is made negative (this kicks up the tail of the curve on small scales). This falls in line with previous best fit attempts made by eye, which suggested a similar necessity for a negative logT_AGN value in order to best match the test data.
#
# This is all reassuring as it tells me that the code is working well and seems to be doing what I was hoping it would (at least I think). I will now attempt to run it overnight (approximately 10 hours). This should give me an appoximately step count of 500. Though not significantly larger, I think it would give much better results, especially once I change the lower bound on the logT_AGN value I'm hoping that the larger sampling will make the resulting contor plots less noisy.
#
# Data was saved under '120_sample_test.npy' so that it could be referenced later as needed.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import camb
import emcee
import matplotlib as mpl
from matplotlib import pyplot as plt
import corner
import numpy as np
import mpl_toolkits.axes_grid1 as axgrid
from mpl_toolkits.axes_grid1 import make_axes_locatable
from scipy.optimize import minimize
from IPython.display import display, Math

plt.rcParams['mathtext.fontset'], plt.rcParams['font.family'] = 'stix', 'STIXGeneral'
plt.rcParams.update({'font.size': 17})

# %% [markdown]
# ### Creating "fake" oberservational data

# %%
pars_test = camb.set_params(H0=67.5, 
                            ombh2=0.022, 
                            omch2=0.120*1.2, 
                            redshifts=[0], 
                            kmax=10, 
                            As=2e-9, 
                            ns=0.96, 
                            halofit_version='mead2020_feedback', 
                            HMCode_A_baryon = 0, 
                            HMCode_eta_baryon = 0, 
                            HMCode_logT_AGN = -10)
                            # zero the HMCode to get a universe without baryonic feedback
results_test = camb.get_transfer_functions(pars_test)
kh_test, _, pk_test = results_test.get_nonlinear_matter_power_spectrum(hubble_units=True, k_hunit=True)

kh_data = kh_test
pk_data = pk_test[0]

pk_err = 0.10*pk_data # creating error

# %% [markdown]
# ## Using piecing method:

# %% [markdown]
# ### Creating likelihood function using 'mead2020'

# %%
def log_likelihood_mead(theta, x, y, yerr): 
    # theta = [A, eta, logT_AGN] params, x --> kh_data, y --> pk_data, yerr --> pk_err
    A, eta, logT_AGN = theta
    model = camb.set_params(H0=67.5, ombh2=0.022, omch2=0.122, redshifts=[0], kmax=10, As=2e-9, ns=0.96, 
                           halofit_version='mead', 
                           HMCode_A_baryon = A, 
                           HMCode_eta_baryon = eta, 
                           HMCode_logT_AGN = logT_AGN)
    results = camb.get_transfer_functions(model)
    kh, _, pk = results.get_nonlinear_matter_power_spectrum(hubble_units=True, k_hunit=True)
    pk = pk[0]
    sigma2 = yerr**2
    return -0.5 * np.sum((y - pk)**2 / sigma2 + np.log(sigma2))

# %%
nll_mead = lambda *args: -log_likelihood_mead(*args) 
# maximizing the likelihood is the same as minimizing the negative of the liklihood
initial = np.array([3.13, 0.603, 7.8]) # using default HMCode values
soln_mead = minimize(nll_mead, initial, args=(kh_data, pk_data, pk_err))
A_ml_mead, eta_ml_mead, logT_AGN_ml_mead = soln_mead.x # maximum likelihood values
print('"mead" maximum likelihood values:', soln_mead.x)
# Out:
# "mead" maximum likelihood values: [ 3.14322588 -0.38471244  7.8       ]

# %% [markdown]
# ### Creating likelihood function using 'mead2020_feedback'

# %%
def log_likelihood_feedback(theta, x, y, yerr): 
    # theta = [A, eta, logT_AGN] params, x --> kh_data, y --> pk_data, yerr --> pk_err
    A, eta, logT_AGN = theta
    model = camb.set_params(H0=67.5, ombh2=0.022, omch2=0.122, redshifts=[0], kmax=10, As=2e-9, ns=0.96, 
                           halofit_version='mead2020_feedback', 
                           HMCode_A_baryon = A, 
                           HMCode_eta_baryon = eta, 
                           HMCode_logT_AGN = logT_AGN)
    results = camb.get_transfer_functions(model)
    kh, _, pk = results.get_nonlinear_matter_power_spectrum(hubble_units=True, k_hunit=True)
    pk = pk[0]
    sigma2 = yerr**2
    return -0.5 * np.sum((y - pk)**2 / sigma2 + np.log(sigma2))

# %%
nll_feedback = lambda *args: -log_likelihood_feedback(*args) 
# maximizing the likelihood is the same as minimizing the negative of the liklihood
initial = np.array([3.13, 0.603, 7.8]) # using default HMCode values
soln_feedback = minimize(nll_feedback, initial, args=(kh_data, pk_data, pk_err))
A_ml_feedback, eta_ml_feedback, logT_AGN_ml_feedback = soln_feedback.x # maximum likelihood values
print('"mead2020_feedback" maximum likelihood values:', soln_feedback.x)
# Out:
# "mead2020_feedback" maximum likelihood values: [3.13  0.603 6.79 ]

# %% [markdown]
# ### Piecing maximum likelihood values together...

# %%
pieced_ml = np.array([A_ml_mead, eta_ml_mead, logT_AGN_ml_feedback])
print('Pieced maximumum likelihood estimates:', pieced_ml)
# Out:
# Pieced maximumum likelihood estimates: [ 3.14322588 -0.38471244  6.79      ]

# %% [markdown]
# ### MCMC

# %%
def log_prior(theta): # sets up priors on theta
    A, eta, logT_AGN = theta
    if -5.0 < A < 10.0 and -5.0 < eta < 5.0 and -5 < logT_AGN < 20.0:
        return 0.0
    return -np.inf

# %%
def log_probability(theta, x, y, yerr):
    # theta = [A, eta, logT_AGN] params, x --> kh_data, y --> pk_data, yerr --> pk_err
    lp = log_prior(theta) 
    if not np.isfinite(lp): 
        return -np.inf
    return lp + log_likelihood_feedback(theta, x, y, yerr)

# %%
pos = pieced_ml + 1e-4 * np.random.randn(32, 3) ## not sure what nwalkers value would be best 
## would increading the number of walkers make it run faster?
nwalkers, ndim = pos.shape

sampler = emcee.EnsembleSampler(nwalkers,
                                ndim, 
                                log_probability, 
                                args=(kh_data, pk_data, pk_err))


sampler.run_mcmc(pos, 120, progress=True);
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [2:39:13<00:00, 79.61s/it]

# %%
samples = sampler.get_chain()
np.save('120_sample_test.npy', samples)

tau = sampler.get_autocorr_time()
print('Integrated autocorrelation time:', tau)
# Out:
# ---------------------------------------------------------------------------
# AutocorrError                             Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10988/2307100217.py in <module>
#       2 np.save('120_sample_test.npy', samples)
#       3
# ----> 4 tau = sampler.get_autocorr_time()
#       5 print('Integrated autocorrelation time:', tau)
#
# ~\anaconda3\lib\site-packages\emcee\ensemble.py in get_autocorr_time(self, **kwargs)
#     603
#     604     def get_autocorr_time(self, **kwargs):
# --> 605         return self.backend.get_autocorr_time(**kwargs)
#     606
#     607     get_autocorr_time.__doc__ = Backend.get_autocorr_time.__doc__
#
# ~\anaconda3\lib\site-packages\emcee\backends\backend.py in get_autocorr_time(self, discard, thin, **kwargs)
#     148         """
#     149         x = self.get_chain(discard=discard, thin=thin)
# --> 150         return thin * autocorr.integrated_time(x, **kwargs)
#     151
#     152     @property
#
# ~\anaconda3\lib\site-packages\emcee\autocorr.py in integrated_time(x, c, tol, quiet)
#     110         msg += "N/{0} = {1:.0f};\ntau: {2}".format(tol, n_t / tol, tau_est)
#     111         if not quiet:
# --> 112             raise AutocorrError(tau_est, msg)
#     113         logger.warning(msg)
#     114
#
# AutocorrError: The chain is shorter than 50 times the integrated autocorrelation time for 3 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 2;
# tau: [11.48568749  8.95266183 16.19175362]

# %%
fig, axes = plt.subplots(3, figsize=(10, 7), sharex=True)
labels = ['A_baryon', 'eta_baryon', 'logT_AGN']
for i in range(ndim):
    ax = axes[i]
    ax.plot(samples[:, :, i], "k", alpha=0.3)
    ax.set_xlim(0, len(samples)-1)
    ax.set_ylabel(labels[i])
    ax.yaxis.set_label_coords(-0.1, 0.5)

axes[-1].set_xlabel('step number');

# %%
flat_samples = sampler.get_chain(discard=25, thin=12, flat=True) ## not sure about discard and thin values
print(flat_samples.shape)

fig = corner.corner(flat_samples, labels=labels, truths=initial);

# Not sure what to put into the 'truths' arg because I don't actually know what values of A, eta, and logT_AGN will
# reproduce the test observational data, so I made equal to HMCode defaults -- might be misunderstanding argument?
# Out:
# WARNING:root:Too few points to create valid contours
# (352, 3)

# %%
labels = ['A-baryon', 'eta-baryon', 'logT_{AGN}']

for i in range(ndim):
    mcmc = np.percentile(flat_samples[:, i], [16, 50, 84])
    q = np.diff(mcmc)
    txt = "\mathrm{{{3}}} = {0:.3f}_{{-{1:.3f}}}^{{{2:.3f}}}"
    txt = txt.format(mcmc[1], q[0], q[1], labels[i])
    display(Math(txt))
# Out:
# $\displaystyle \mathrm{A-baryon} = 3.943_{-4.159}^{4.378}$
# $\displaystyle \mathrm{eta-baryon} = 0.330_{-2.397}^{3.650}$
# $\displaystyle \mathrm{logT_{AGN}} = 3.505_{-5.805}^{2.713}$

# %% [markdown]
# ### Quick plot for sanity check

# %%
def baryon_feedback(A, eta, logT_AGN):
    pars = camb.set_params(H0=67.5, ombh2=0.022, omch2=0.122, redshifts=[0], kmax=10, As=2e-9, ns=0.96, 
                           halofit_version='mead2020_feedback', 
                           HMCode_A_baryon = A, 
                           HMCode_eta_baryon = eta, 
                           HMCode_logT_AGN = logT_AGN)
    results = camb.get_transfer_functions(pars)
    kh, _ , pk = results.get_nonlinear_matter_power_spectrum(hubble_units=True, k_hunit=True)
    return kh, pk[0]

# %%
kh_model, pk_model = baryon_feedback(3.943, 0.330, -5.805)
# kh_test, pk_test = baryon_feedback(3.13, 0.603, 7.8)

plt.figure(figsize=(8,6))
plt.errorbar(kh_data, pk_data, yerr=pk_err, color='k', label='Observational data\n[omch2*1.2]')
plt.plot(kh_model, pk_model, "--g", label="Maximum likelihood")
# plt.plot(kh_test, pk_test, 'r')
plt.xscale('log')
plt.yscale('log')
plt.legend(bbox_to_anchor=(1,1), loc='upper left')
plt.ylabel('$P_m(k)$ [($h^{-1}Mpc)^3$]')
plt.xlabel('Wavenumber, k [h/Mpc]');

# %%
flat_samples = sampler.get_chain(flat=True) # same thing just got rid of discard and thin kwargs
print(flat_samples.shape)

fig = corner.corner(flat_samples, labels=labels, truths=initial);
# Out:
# (3840, 3)

# %%
labels = ['A', 'eta', 'logT_{AGN}']

for i in range(ndim):
    mcmc = np.percentile(flat_samples[:, i], [16, 50, 84])
    q = np.diff(mcmc)
    txt = "\mathrm{{{3}}} = {0:.3f}_{{-{1:.3f}}}^{{{2:.3f}}}"
    txt = txt.format(mcmc[1], q[0], q[1], labels[i])
    display(Math(txt))
# Out:
# $\displaystyle \mathrm{A} = 3.192_{-2.031}^{4.567}$
# $\displaystyle \mathrm{eta} = -0.350_{-1.254}^{3.580}$
# $\displaystyle \mathrm{logT_{AGN}} = 4.463_{-6.314}^{2.327}$

# %% [markdown]
# #### Final Questions and Thoughts:
# Questions:
#    - What would be a good number of walkers?
#    - Would increasing the number of walkers make the process faster or slower?
#    - Generally really slow, running at approximately 20 samples per 30 minutes. Can I do anything to help this out?
#    - Not sure how to handle the discard and thin kwargs
#    - Not sure if I'm understanding how the autocorrelation time is being used. Is it even useful for us?
#    - Contor plot is kinda messy... Is this concerning? Would more samples likely "silence" the "noise"?
#    - I just used the same code used in the emcee sample notebook to report best fit params. What would be the best way to document results?
#    - Something I personally noticed: each iteration took about 90s in the beginning and then, slowly took less time to run (~60s per iteration) --> got faster with time?
#
# Thoughts:
# This was my first attempt at a long integration run and I think it generally went well! Moving on to 500 samples and hoping for the best!
